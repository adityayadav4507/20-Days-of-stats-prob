# %% [markdown]
# <a href="https://colab.research.google.com/github/adityayadav4507/20-Days-of-stats-prob/blob/main/6_Day_Central_therorm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
n=10
p=0.5
sample=1000

dist=np.random.binomial(n,p,sample)
plt.hist(dist,bins=20)
plt.show()

# %%
n=10
p=0.1
sample=1000

dist=np.random.binomial(n,p,sample)
plt.hist(dist,bins=10)
plt.show()

# %%
n=10
p=0.9
sample=1000

dist=np.random.binomial(n,p,sample)
plt.hist(dist,bins=20)
plt.show()

# %% [markdown]
# # central theorm

# %% [markdown]
# # 1. uniform dist

# %%
# set parameters
num_samples=1000
sample_size=30
distrbution_range=(0,1)

# generate samples form  uniform distribution
samples=np.random.uniform(distrbution_range[0],distrbution_range[1],(num_samples,sample_size)) # each set =30 , no.of set 1000

plt.hist(samples)
# Out:
# (array([[ 83.,  95.,  97., 100., 115.,  91.,  89., 119., 115.,  96.],
#         [105., 104., 102.,  89., 114., 103., 105.,  91.,  90.,  97.],
#         [ 98.,  87., 102.,  84., 112., 102.,  96., 117., 105.,  97.],
#         [ 94.,  98., 105.,  92., 111.,  81., 101., 111., 102., 105.],
#         [ 99.,  93., 101.,  89., 109., 110.,  89.,  91., 104., 115.],
#         [107., 109., 103., 118.,  93.,  95.,  85.,  97., 107.,  86.],
#         [ 93., 102.,  99., 103., 112., 100.,  90.,  87., 115.,  99.],
#         [104.,  91., 101., 105.,  94., 100., 105.,  84., 104., 112.],
#         [ 85.,  96.,  84.,  88., 105., 113., 117.,  95., 114., 103.],
#         [107., 106.,  93., 116.,  93., 107.,  92.,  99., 101.,  86.],
#         [ 98.,  97.,  86.,  97.,  98.,  96., 103., 108., 112., 105.],
#         [ 94., 116.,  94., 103.,  96.,  92., 106.,  87., 117.,  95.],
#         [106., 110., 102., 102., 105.,  91.,  81.,  96., 113.,  94.],
#         [103., 100.,  93., 105.,  90., 110.,  86., 110., 108.,  95.],
#         [ 98., 105.,  90., 102., 108., 108., 109.,  91.,  87., 102.],
#         [ 84.,  96., 108., 122.,  97.,  93.,  94., 104., 107.,  95.],
#         [ 84., 111.,  97.,  96., 127.,  91., 100., 103.,  94.,  97.],
#         [110., 103., 104., 104., 106.,  93.,  82., 103.,  99.,  96.],
#         [108.,  84., 106., 100., 102.,  90., 102., 106., 108.,  94.],
#         [111.,  85., 111.,  96., 105.,  94.,  91.,  98.,  99., 110.],
#         [ 88.,  92.,  96., 101., 124., 105., 108.,  98.,  89.,  99.],
#         [103.,  99.,  85., 100., 106., 106., 104.,  95., 105.,  97.],
#         [107.,  86.,  97.,  99., 108.,  94., 130., 100.,  88.,  91.],
#         [ 93.,  90., 107.,  99., 107., 136.,  90.,  89.,  90.,  99.],
#         [ 92., 123., 103., 117.,  90.,  88.,  92.,  89., 106., 100.],
#         [ 90.,  97., 104., 113.,  85.,  92.,  97., 104., 111., 107.],
#         [ 88., 100.,  93., 101., 101., 108.,  94., 107.,  90., 118.],
#         [ 88., 103., 107.,  95., 102.,  96.,  95., 100., 110., 104.],
#         [ 95.,  95., 112.,  76.,  98., 103., 103., 107.,  92., 119.],
#         [115., 103., 105.,  94.,  87., 107.,  90.,  98., 103.,  98.]]),
#  array([1.19129075e-04, 1.00101970e-01, 2.00084811e-01, 3.00067652e-01,
#         4.00050493e-01, 5.00033334e-01, 6.00016175e-01, 6.99999016e-01,
#         7.99981857e-01, 8.99964699e-01, 9.99947540e-01]),
#  <a list of 30 BarContainer objects>)

# %%
# sample means
sample_mean=np.mean(samples,axis=1)
plt.hist(sample_mean,bins=30,density=True)
plt.xlabel('sample mean')
plt.ylabel('density')
plt.show()

# %% [markdown]
# # 2. expo dist

# %%
# set parameters
num_samples=1000
sample_size=30
lambda_sample=2

# generate samples form  expo
samples=np.random.exponential(lambda_sample,(num_samples,sample_size)) # each set =30 , no.of set 1000

plt.hist(samples)
# Out:
# (array([[679., 223.,  70.,  21.,   3.,   2.,   1.,   1.,   0.,   0.],
#         [665., 232.,  65.,  29.,   7.,   2.,   0.,   0.,   0.,   0.],
#         [699., 202.,  68.,  20.,   6.,   4.,   1.,   0.,   0.,   0.],
#         [669., 224.,  67.,  30.,   6.,   3.,   0.,   1.,   0.,   0.],
#         [664., 222.,  74.,  28.,  10.,   2.,   0.,   0.,   0.,   0.],
#         [695., 211.,  62.,  25.,   6.,   1.,   0.,   0.,   0.,   0.],
#         [645., 226.,  94.,  23.,   8.,   2.,   2.,   0.,   0.,   0.],
#         [682., 225.,  66.,  20.,   6.,   1.,   0.,   0.,   0.,   0.],
#         [686., 215.,  73.,  11.,  11.,   3.,   0.,   1.,   0.,   0.],
#         [662., 224.,  78.,  29.,   6.,   1.,   0.,   0.,   0.,   0.],
#         [651., 241.,  70.,  26.,   7.,   2.,   3.,   0.,   0.,   0.],
#         [673., 224.,  68.,  26.,   6.,   2.,   0.,   1.,   0.,   0.],
#         [657., 237.,  78.,  19.,   4.,   4.,   1.,   0.,   0.,   0.],
#         [679., 225.,  70.,  16.,   7.,   3.,   0.,   0.,   0.,   0.],
#         [660., 229.,  74.,  24.,   7.,   5.,   1.,   0.,   0.,   0.],
#         [670., 220.,  77.,  16.,  11.,   4.,   0.,   1.,   1.,   0.],
#         [675., 247.,  53.,  14.,   5.,   4.,   1.,   1.,   0.,   0.],
#         [643., 248.,  82.,  19.,   6.,   1.,   0.,   1.,   0.,   0.],
#         [688., 209.,  65.,  25.,   9.,   3.,   1.,   0.,   0.,   0.],
#         [669., 211.,  80.,  30.,   8.,   2.,   0.,   0.,   0.,   0.],
#         [657., 239.,  68.,  20.,  11.,   2.,   1.,   2.,   0.,   0.],
#         [682., 210.,  75.,  18.,   8.,   4.,   2.,   0.,   0.,   1.],
#         [677., 232.,  61.,  16.,   6.,   6.,   1.,   0.,   0.,   1.],
#         [679., 211.,  73.,  24.,   8.,   2.,   2.,   1.,   0.,   0.],
#         [681., 207.,  77.,  21.,   8.,   5.,   1.,   0.,   0.,   0.],
#         [661., 231.,  72.,  26.,   8.,   2.,   0.,   0.,   0.,   0.],
#         [685., 204.,  76.,  22.,   9.,   3.,   1.,   0.,   0.,   0.],
#         [693., 211.,  68.,  18.,   8.,   0.,   2.,   0.,   0.,   0.],
#         [672., 222.,  74.,  16.,  10.,   1.,   4.,   1.,   0.,   0.],
#         [669., 222.,  68.,  30.,   9.,   1.,   1.,   0.,   0.,   0.]]),
#  array([5.65299575e-05, 2.22938029e+00, 4.45870405e+00, 6.68802781e+00,
#         8.91735157e+00, 1.11466753e+01, 1.33759991e+01, 1.56053228e+01,
#         1.78346466e+01, 2.00639704e+01, 2.22932941e+01]),
#  <a list of 30 BarContainer objects>)

# %%
# mean of samples
sample_mean=np.mean(samples,axis=1)
plt.hist(sample_mean,bins=30,density=True)
plt.xlabel('sample mean')
plt.ylabel('density')
plt.show()

# %% [markdown]
# # 3. poisson dist
# # 4. gamma dist
# # 5. bionomial dist

# %%
# set parameters

num_samples=1000
sample_size=30

# 3. poision dist parametrs
poisson_lambda=5
# 4. gamma dist parameters
gamma_shape=2
gamma_scale=1
# 5 . bionomial dist
n_binomial=10
p_binomial=0.5

# Generate samples from the dist
samples_poisson=np.random.poisson(poisson_lambda,(num_samples,sample_size))
samples_gamma=np.random.gamma(gamma_shape,gamma_scale,(num_samples,sample_size))
samples_binomial=np.random.binomial(n_binomial,p_binomial,(num_samples,sample_size))

# calculate means
poisson_mean=np.mean(samples_poisson,axis=1)
gamma_mean=np.mean(samples_gamma,axis=1)
binomial_mean=np.mean(samples_binomial,axis=1)

# plot histogram of samples mean

fig ,axs = plt.subplots(1,3,figsize=(15,5))

# 3. poisson dist
axs[0].hist(poisson_mean,bins=30,density=True)
axs[0].set_xlabel('sample mean')
axs[0].set_ylabel('density')
axs[0].set_title('poisson distribution')

# 4. gamma dist
axs[1].hist(gamma_mean,bins=30,density=True)
axs[1].set_xlabel('sample mean')
axs[1].set_ylabel('density')
axs[1].set_title('gamma distribution')

# 5. bionomial dist
axs[2].hist(binomial_mean,bins=30,density=True)
axs[2].set_xlabel('sample mean')
axs[2].set_ylabel('density')
axs[2].set_title('binomial distribution')
# Out:
# Text(0.5, 1.0, 'binomial distribution')

# %% [markdown]
# # mean of sample = mean of population

# %%
# set parametrs
num_samples=10000
sample_size=50
gamma_shape=2
gamma_scale=1


# mean of population
population_mean=gamma_scale*gamma_shape
population_var=gamma_shape*gamma_scale**2

# generate samples from gamma distribution
samples=np.random.gamma(gamma_shape,gamma_scale,(num_samples,sample_size))

samples_means=np.mean(samples,axis=1)

# mean of sample

sample_mean=np.mean(samples_means)
sample_var=np.var(samples_means)


print(f"population mean : {population_mean}")
print(f"population variance : {population_var}")
print()
print(f"sample mean : {sample_mean}")
print(f"sample variance : {sample_var}")
# Out:
# population mean : 2
# population variance : 2
#
# sample mean : 1.9981781331860127
# sample variance : 0.040053277605624805

# %%
2/50
# Out:
# 0.04

# %% [markdown]
# # titanic data

# %%
df=pd.read_csv('/content/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=df.drop(columns=['Survived'])

# %%
df['Fare'].plot(kind='kde') # right skewed
# Out:
# <Axes: ylabel='Density'>

# %%
# sample
sample_size=50
# 100 times
sample=[]

for i in range(100):

  sample.append(df['Fare'].sample(50).values.tolist())

# %%
sample=np.array(sample)
sample
# Out:
# array([[ 7.75  ,  7.75  , 56.4958, ...,  7.75  , 26.    , 12.475 ],
#        [24.15  ,  7.8958, 30.5   , ..., 26.    , 22.525 ,  7.8958],
#        [10.5   , 26.    , 26.    , ..., 18.    , 59.4   ,  7.8542],
#        ...,
#        [21.075 , 56.4958,  7.8958, ..., 77.9583,  8.05  , 14.4583],
#        [ 7.775 ,  8.1375,  7.8958, ...,  7.25  , 90.    ,  7.8958],
#        [ 9.5   , 22.025 , 24.15  , ..., 49.5   ,  0.    ,  8.5167]])

# %%
sample_mean=sample.mean(axis=1)
import seaborn as sns

sns.kdeplot(sample_mean)
# Out:
# <Axes: ylabel='Density'>

# %%
sample_mean.mean()
# Out:
# np.float64(32.20365076)

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
sample_mean.std()/np.sqrt(50)
# Out:
# np.float64(0.8013194881072371)

# %%
lower_limit=sample_mean.mean() - 2*sample_mean.std()/np.sqrt(50)
upper_limit=sample_mean.mean() + 2*sample_mean.std()/np.sqrt(50)

print("range",lower_limit,"-",upper_limit) # range of mean of population with 95 % confidence
# Out:
# range 30.601011783785527 - 33.806289736214474
